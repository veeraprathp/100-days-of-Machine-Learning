# %% [markdown]
# <a href="https://colab.research.google.com/github/veeraprathp/Machine-Learning/blob/main/Simple_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
dataset=pd.read_csv("/content/Salary_Data.csv")
x=dataset.iloc[:, :-1].values
y=dataset.iloc[:, -1].values

# %% [markdown]
# Train and Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# training the simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regeressor = LinearRegression()
regeressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# predicting the test set results

# %%
y_pred=regeressor.predict(x_test)
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %% [markdown]
# Visualising the training set results

# %%
plt.scatter(x_train,y_train, color ='red')
plt.plot(x_train,regeressor.predict(x_train),color='blue')
plt.title ('salary vs Experience (Training set)')
plt.xlabel('years of experience')
plt.ylabel('years of Experience')
plt.show()

# %% [markdown]
# Visulising the test result set results

# %%
plt.scatter(x_test,y_test, color ='red')
plt.plot(x_test,regeressor.predict(x_test),color='blue')
plt.title ('salary vs Experience (Test set)')
plt.xlabel('years of experience')
plt.ylabel('years of Experience')
plt.show()
